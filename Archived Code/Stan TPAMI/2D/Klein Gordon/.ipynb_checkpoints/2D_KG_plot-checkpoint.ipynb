# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from torch.nn.parameter import Parameter

import numpy as np
import time
from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io

from smt.sampling_methods import LHS
from scipy.io import savemat

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

device = torch.device('cpu')

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cpu

# %%
def true_2D_1(xt): #True function for 2D_1 Klein Gordon Equation x \in [-50,50] , t \in [0,10]
    y = xt[:,0]*np.cos(xt[:,1])
    return y.reshape(-1,1)

# %%
x = np.linspace(-5,5,500).reshape(-1,1)
t = np.linspace(0,10,1000).reshape(-1,1)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

y_true = true_2D_1(xt)

bound_pts_idx = ((X == -5) + (X == 5) + (T == 0)).reshape(-1,)

xt_bound = xt[bound_pts_idx,:]
y_bound = y_true[bound_pts_idx,:]


xt_test_tensor = torch.from_numpy(xt).float().to(device)


lb_xt = xt[0]
ub_xt = xt[-1]

# %%
data_tanhxtanh = scipy.io.loadmat('QCRE_2D_1_tanhxtanh_NW_new.mat')
data_atanh = scipy.io.loadmat('QCRE_2D_1_atanh_NW_new.mat')
data_tanh = scipy.io.loadmat('QCRE_2D_1_tanh_new.mat')


num_steps = 1000

# %%
train_loss_tanhxtanh =  data_tanhxtanh['train_loss']
train_loss_atanh =  data_atanh['train_loss']
train_loss_tanh =  data_tanh['train_loss']

mean_train_loss_tanhxtanh = np.zeros((num_steps,1))
mean_train_loss_atanh = np.zeros((num_steps,1))
mean_train_loss_tanh = np.zeros((num_steps,1))


for i in range(10):
    mean_train_loss_tanhxtanh = mean_train_loss_tanhxtanh + train_loss_tanhxtanh[0][i][0,:num_steps].reshape(-1,1)
    mean_train_loss_atanh = mean_train_loss_atanh + train_loss_atanh[0][i][0,:num_steps].reshape(-1,1)
    mean_train_loss_tanh = mean_train_loss_tanh + train_loss_tanh[0][i][0,:num_steps].reshape(-1,1)
    
mean_train_loss_tanhxtanh = mean_train_loss_tanhxtanh/10
mean_train_loss_atanh = mean_train_loss_atanh/10
mean_train_loss_tanh = mean_train_loss_tanh/10

fig, ax = plt.subplots()
ax.plot(mean_train_loss_tanhxtanh,'r',linewidth = 2,label = 'Proposed')
ax.plot(mean_train_loss_atanh,'b--',linewidth = 2, label = 'N-LAAF')
ax.plot(mean_train_loss_tanh,'k-.',linewidth = 2, label = 'tanh')


ax.set_yscale('log')
ax.legend(prop={'size':14})
ax.set_ylim([0,1000])
ax.set_title('Training Loss', fontsize=14)
ax.set_xlabel('Epochs',fontsize=14, math_fontfamily='cm')
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
plt.savefig('2D_1_train_loss.eps', format='eps',pad_inches=0, bbox_inches='tight')
# Out:
# /home/smartlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
test_loss_tanhxtanh =  data_tanhxtanh['test_loss']
test_loss_atanh =  data_atanh['test_loss']
test_loss_tanh =  data_tanh['test_loss']

mean_test_loss_tanhxtanh = np.zeros((num_steps,1))
mean_test_loss_atanh = np.zeros((num_steps,1))
mean_test_loss_tanh = np.zeros((num_steps,1))


for i in range(10):
    mean_test_loss_tanhxtanh = mean_test_loss_tanhxtanh + test_loss_tanhxtanh[0][i][0,:num_steps].reshape(-1,1)
    mean_test_loss_atanh = mean_test_loss_atanh + test_loss_atanh[0][i][0,:num_steps].reshape(-1,1)
    mean_test_loss_tanh = mean_test_loss_tanh + test_loss_tanh[0][i][0,:num_steps].reshape(-1,1)
    
mean_test_loss_tanhxtanh = mean_test_loss_tanhxtanh/10
mean_test_loss_atanh = mean_test_loss_atanh/10
mean_test_loss_tanh = mean_test_loss_tanh/10

fig, ax = plt.subplots()
ax.plot(mean_test_loss_tanhxtanh,'r',linewidth = 2,label = 'Proposed')
ax.plot(mean_test_loss_atanh,'b--',linewidth = 2,label ='N-LAAF')
ax.plot(mean_test_loss_tanh,'k-.',linewidth = 2,label ='tanh')


ax.set_yscale('log')
ax.legend(prop={'size':14})
#ax.set_ylim([3,10])
ax.set_title('Test Loss', fontsize=14)
ax.set_xlabel('Epochs',fontsize=14, math_fontfamily='cm')
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
plt.savefig('2D_1_test_loss.eps', format='eps',pad_inches=0, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
print(mean_test_loss_tanhxtanh[num_steps - 1])
print(mean_test_loss_atanh[num_steps - 1])
print(mean_test_loss_tanh[num_steps - 1])
# Out:
# [0.54894217]
# [1.54245025]
# [2.61172042]

# %%
beta_tanhxtanh =  data_tanhxtanh['beta']

beta_history = beta_tanhxtanh[0][0][:num_steps,35,8] #For the first repetition

fig, ax = plt.subplots()
ax.plot(beta_history,'r')

ax.set_title('Value', fontsize=14, math_fontfamily='cm')
ax.set_xlabel('Epochs', fontsize=14, math_fontfamily='cm')
ax.set_ylabel('$\\beta $',fontsize=18, math_fontfamily='cm')
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
plt.savefig('2D_1_beta_history.eps', format='eps',pad_inches=0, bbox_inches='tight')

# %%
for i in range(10):
    print(i)
    print(test_loss_tanhxtanh[0][i][0,-1])
    print(train_loss_atanh[0][i][0,-1])
    print(train_loss_tanh[0][i][0,-1])
# Out:
# 0
# 0.012326581179573007
# 0.8374697
# 0.0062518823
# 1
# 2.0649812135963006
# 1.2610433
# 0.50596404
# 2
# 0.006556472044664043
# 0.0036919576
# 0.10161433
# 3
# 0.012452396880183098
# 1.3539637
# 31.144928
# 4
# 0.001121468091774604
# 0.02814719
# 0.4439499
# 5
# 0.00035593575460539476
# 10.278315
# 0.82598346
# 6
# 0.03445543641418323
# 0.089402966
# 0.77084935
# 7
# 0.0005868040468503737
# 0.26206213
# 0.009102503
# 8
# 0.0005917138461412052
# 0.0023848307
# 0.03725048
# 9
# 0.02410247768572891
# 0.11027625
# 19.343906

# %%
class Sequentialmodel_tanhxtanh(nn.Module):
    
    def __init__(self,layers):
        super().__init__() #call __init__ from parent class 
              
        'activation function'
        self.activation = nn.Tanh()

     
        'loss function'
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        'Initialise neural network as a list using nn.Modulelist'  
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        self.iter = 0
        
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)
            
        
        self.beta = Parameter(torch.ones((50,len(layers)-2)))
        self.beta.requiresGrad = True
        
        self.train_loss = []
        self.test_loss = []
        
        self.beta_val = []
            
    'foward pass'
    def forward(self,xt):
        if torch.is_tensor(xt) != True:         
            xt = torch.from_numpy(xt)                
        
        ubxt = torch.from_numpy(ub_xt).float().to(device)
        lbxt = torch.from_numpy(lb_xt).float().to(device)
    
                      
        #preprocessing input 
        xt = (xt - lbxt)/(ubxt - lbxt)
        
        #convert to float
        a = xt.float()
        
        for i in range(len(layers)-2):
            z = self.linears[i](a)
            a = self.activation(z) + self.beta[:,i]*z*self.activation(z)
            
        a = self.linears[-1](a) 
         
        return a
                        
    def loss_BC(self,xt,y):
                
        loss_bc = self.loss_function(self.forward(xt), y)
                
        return loss_bc
    
    def loss_PDE(self, xt_coll, f_hat):
        
        g = xt_coll.clone()             
        g.requires_grad = True
        y = self.forward(g) 
        
        
        y_x_t = autograd.grad(y,g,torch.ones([xt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        
        y_xx_tt = autograd.grad(y_x_t,g,torch.ones(xt_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        #du_dx = u_x_t[:,[0]]
        
        d2y_dx2 = y_xx_tt[:,[0]]
        d2y_dt2 = y_xx_tt[:,[1]]    
        

        f = d2y_dt2 - d2y_dx2 + torch.pow(y,2) + (g[:,0]*torch.cos(g[:,1])).reshape(-1,1) - (torch.pow(g[:,0],2)*torch.pow(torch.cos(g[:,1]),2)).reshape(-1,1)
        
        loss_f = self.loss_function(f,f_hat)
                
        return loss_f
    
    def loss(self,xt_BC,y_BC,xt_coll,f_hat):

        loss_BC = self.loss_BC(xt_BC,y_BC)
        loss_f = self.loss_PDE(xt_coll,f_hat)
        
        loss_val = loss_BC + loss_f
        
        return loss_val
     
    'callable for optimizer'                                       
    def closure(self):
        optimizer.zero_grad()
        
        loss = self.loss(xt_BC, y_BC, xt_coll,f_hat)
        self.train_loss.append(loss.cpu().detach().numpy())
        
        y_pred = self.test(xt_test_tensor)
        self.test_loss.append(np.mean(np.square(y_pred.reshape(-1,1) - y_true.reshape(-1,1))))
        self.beta_val.append(self.beta.cpu().detach().numpy())
        
        print(self.iter,"Train Loss",self.train_loss[-1],"Test Loss",self.test_loss[-1])
        
        loss.backward()
        self.iter += 1
  

        return loss        
    'test neural network'
    def test(self,xt_test_tensor):
        y_pred = self.forward(xt_test_tensor)
        y_pred = y_pred.cpu().detach().numpy()
   
        return y_pred

# %%
x = np.linspace(-5,5,500).reshape(-1,1)
t = np.linspace(0,10,1000).reshape(-1,1)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

y_true = true_2D_1(xt)

xt_test_tensor = torch.from_numpy(xt).float().to(device)

layers = np.array([2,50,50,50,50,50,50,50,50,50,1]) #9 hidden layers
model_tanhxtanh = Sequentialmodel_tanhxtanh(layers)

model_tanhxtanh.load_state_dict(torch.load('QCRE_2D_1_tanhxtanh_NW_new_3.pt'))

y_pred_tanhxtanh = model_tanhxtanh.test(xt_test_tensor)

# %%
class Sequentialmodel_atanh(nn.Module):
    
    def __init__(self,layers):
        super().__init__() #call __init__ from parent class 
              
        'activation function'
        self.activation = nn.Tanh()

     
        'loss function'
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        'Initialise neural network as a list using nn.Modulelist'  
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        self.iter = 0
        
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)
            
        
        self.alpha = Parameter(torch.ones((50,len(layers)-2)))
        self.alpha.requiresGrad = True
        
        self.train_loss = []
        self.test_loss = []
        
        self.alpha_val = []
        
        self.n = torch.tensor(1.0)
            
    'foward pass'
    def forward(self,xt):
        if torch.is_tensor(xt) != True:         
            xt = torch.from_numpy(xt)                
        
        ubxt = torch.from_numpy(ub_xt).float().to(device)
        lbxt = torch.from_numpy(lb_xt).float().to(device)
    
                      
        #preprocessing input 
        xt = (xt - lbxt)/(ubxt - lbxt)
        
        #convert to float
        a = xt.float()
        
        for i in range(len(layers)-2):
            z = self.linears[i](a)
            a = self.activation(self.n*self.alpha[:,i]*z)
            
        a = self.linears[-1](a) 
         
        return a
                        
    def loss_BC(self,xt,y):
                
        loss_bc = self.loss_function(self.forward(xt), y)
                
        return loss_bc
    
    def loss_PDE(self, xt_coll, f_hat):
        
        g = xt_coll.clone()             
        g.requires_grad = True
        y = self.forward(g) 
        
        
        y_x_t = autograd.grad(y,g,torch.ones([xt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        
        y_xx_tt = autograd.grad(y_x_t,g,torch.ones(xt_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        #du_dx = u_x_t[:,[0]]
        
        d2y_dx2 = y_xx_tt[:,[0]]
        d2y_dt2 = y_xx_tt[:,[1]]    
        

        f = d2y_dt2 - d2y_dx2 + torch.pow(y,2) + (g[:,0]*torch.cos(g[:,1])).reshape(-1,1) - (torch.pow(g[:,0],2)*torch.pow(torch.cos(g[:,1]),2)).reshape(-1,1)
        
        loss_f = self.loss_function(f,f_hat)
                
        return loss_f
    
    def loss(self,xt_BC,y_BC,xt_coll,f_hat):

        loss_BC = self.loss_BC(xt_BC,y_BC)
        loss_f = self.loss_PDE(xt_coll,f_hat)
        
        loss_val = loss_BC + loss_f
        
        return loss_val
     
    'callable for optimizer'                                       
    def closure(self):
        optimizer.zero_grad()
        
        loss = self.loss(xt_BC, y_BC, xt_coll,f_hat)
        self.train_loss.append(loss.cpu().detach().numpy())
        
        y_pred = self.test(xt_test_tensor)
        self.test_loss.append(np.mean(np.square(y_pred.reshape(-1,1) - y_true.reshape(-1,1))))
        self.alpha_val.append(self.alpha.cpu().detach().numpy())
        
        print(self.iter,"Train Loss",self.train_loss[-1],"Test Loss",self.test_loss[-1])
        
        loss.backward()
        self.iter += 1
  

        return loss        
    'test neural network'
    def test(self,xt_test_tensor):
        y_pred = self.forward(xt_test_tensor)
        y_pred = y_pred.cpu().detach().numpy()
   
        return y_pred

# %%
x = np.linspace(-5,5,500).reshape(-1,1)
t = np.linspace(0,10,1000).reshape(-1,1)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

y_true = true_2D_1(xt)

xt_test_tensor = torch.from_numpy(xt).float().to(device)

layers = np.array([2,50,50,50,50,50,50,50,50,50,1]) #9 hidden layers
model_atanh = Sequentialmodel_atanh(layers)

model_atanh.load_state_dict(torch.load('QCRE_2D_1_atanh_NW_new_1.pt'))

y_pred_atanh = model_atanh.test(xt_test_tensor)

# %%
class Sequentialmodel_tanh(nn.Module):
    
    def __init__(self,layers):
        super().__init__() #call __init__ from parent class 
              
        'activation function'
        self.activation = nn.Tanh()

     
        'loss function'
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        'Initialise neural network as a list using nn.Modulelist'  
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        self.iter = 0
        
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)
            
        self.train_loss = []
        self.test_loss = []
        
            
    'foward pass'
    def forward(self,xt):
        if torch.is_tensor(xt) != True:         
            xt = torch.from_numpy(xt)                
        
        ubxt = torch.from_numpy(ub_xt).float().to(device)
        lbxt = torch.from_numpy(lb_xt).float().to(device)
    
                      
        #preprocessing input 
        xt = (xt - lbxt)/(ubxt - lbxt)
        
        #convert to float
        a = xt.float()
        
        for i in range(len(layers)-2):
            z = self.linears[i](a)
            a = self.activation(z)
            
        a = self.linears[-1](a) 
         
        return a
                        
    def loss_BC(self,xt,y):
                
        loss_bc = self.loss_function(self.forward(xt), y)
                
        return loss_bc
    
    def loss_PDE(self, xt_coll, f_hat):
        
        g = xt_coll.clone()             
        g.requires_grad = True
        y = self.forward(g) 
        
        
        y_x_t = autograd.grad(y,g,torch.ones([xt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        
        y_xx_tt = autograd.grad(y_x_t,g,torch.ones(xt_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        #du_dx = u_x_t[:,[0]]
        
        d2y_dx2 = y_xx_tt[:,[0]]
        d2y_dt2 = y_xx_tt[:,[1]]    
        

        f = d2y_dt2 - d2y_dx2 + torch.pow(y,2) + (g[:,0]*torch.cos(g[:,1])).reshape(-1,1) - (torch.pow(g[:,0],2)*torch.pow(torch.cos(g[:,1]),2)).reshape(-1,1)
        
        loss_f = self.loss_function(f,f_hat)
                
        return loss_f
    
    def loss(self,xt_BC,y_BC,xt_coll,f_hat):

        loss_BC = self.loss_BC(xt_BC,y_BC)
        loss_f = self.loss_PDE(xt_coll,f_hat)
        
        loss_val = loss_BC + loss_f
        
        return loss_val
     
    'callable for optimizer'                                       
    def closure(self):
        optimizer.zero_grad()
        
        loss = self.loss(xt_BC, y_BC, xt_coll,f_hat)
        self.train_loss.append(loss.cpu().detach().numpy())
        
        y_pred = self.test(xt_test_tensor)
        self.test_loss.append(np.mean(np.square(y_pred.reshape(-1,1) - y_true.reshape(-1,1))))
        
        print(self.iter,"Train Loss",self.train_loss[-1],"Test Loss",self.test_loss[-1])
        
        loss.backward()
        self.iter += 1
  

        return loss        
    'test neural network'
    def test(self,xt_test_tensor):
        y_pred = self.forward(xt_test_tensor)
        y_pred = y_pred.cpu().detach().numpy()
   
        return y_pred

# %%
x = np.linspace(-5,5,500).reshape(-1,1)
t = np.linspace(0,10,1000).reshape(-1,1)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

y_true = true_2D_1(xt)

xt_test_tensor = torch.from_numpy(xt).float().to(device)

layers = np.array([2,50,50,50,50,50,50,50,50,50,1]) #9 hidden layers
model_tanh = Sequentialmodel_tanh(layers)

model_tanh.load_state_dict(torch.load('QCRE_2D_1_tanh_new_9.pt'))

y_pred_tanh = model_tanh.test(xt_test_tensor)

# %%
fig, ax = plt.subplots(1,3)

fig.dpi=300
fig.tight_layout()
cmap = plt.cm.rainbow

img1 = ax[0].imshow(np.abs(y_pred_tanhxtanh - y_true).reshape(500,1000),vmin =0,vmax =4,cmap = cmap,extent=[0,10,5,-5],aspect = 0.75)
img2 = ax[1].imshow(np.abs(y_pred_atanh - y_true).reshape(500,1000),vmin = 0,vmax = 4,cmap = cmap,extent=[0,10,5,-5],aspect = 0.75)
img3 = ax[2].imshow(np.abs(y_pred_tanh - y_true).reshape(500,1000),vmin = 0,vmax = 4,cmap = cmap,extent=[0,10,5,-5],aspect = 0.75)

cbar = fig.colorbar(img1, ax=ax,location = 'top',orientation = 'horizontal', aspect = 50, panchor = (0,1.45),pad = 0.15)
cbar.ax.tick_params(labelsize=6,labelbottom = True,labeltop = False, bottom =True, top = False) 

#ax.set_xticks([0,10]) 
ax[0].set_xlabel('$t$', fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[0].set_ylabel(' $x$',fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[1].set_xlabel('$t$', fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[1].set_ylabel(' $x$',fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[2].set_xlabel('$t$', fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[2].set_ylabel(' $x$',fontsize=8, math_fontfamily='cm', labelpad=0.5)

ax[0].tick_params(axis='x', labelsize=6)
ax[0].tick_params(axis='y', labelsize=6)
ax[0].set_title('Proposed',fontsize=8, math_fontfamily='cm')

ax[1].tick_params(axis='x', labelsize=6)
ax[1].tick_params(axis='y', labelsize=6)
ax[1].set_title('N-LAAF',fontsize=8, math_fontfamily='cm')

ax[2].tick_params(axis='x', labelsize=6)
ax[2].tick_params(axis='y', labelsize=6)
ax[2].set_title('tanh',fontsize=8, math_fontfamily='cm')

fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=None)


plt.savefig('2D_1_error_comparison.eps', format='eps',pad_inches=0, bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,3)

fig.dpi=300
fig.tight_layout()
cmap = plt.cm.rainbow

img1 = ax[0].imshow(y_pred_tanhxtanh.reshape(500,1000),vmin =-5,vmax = 5,cmap = cmap,extent=[0,10,5,-5],aspect = 0.75)
img2 = ax[1].imshow(y_pred_atanh.reshape(500,1000),vmin = -5,vmax = 5,cmap = cmap,extent=[0,10,5,-5],aspect = 0.75)
img3 = ax[2].imshow(y_pred_tanh.reshape(500,1000),vmin = -5,vmax = 5,cmap = cmap,extent=[0,10,5,-5],aspect = 0.75)

cbar = fig.colorbar(img1, ax=ax,location = 'top',orientation = 'horizontal', aspect = 50, panchor = (0,1.45),pad = 0.15)
cbar.ax.tick_params(labelsize=6,labelbottom = True,labeltop = False, bottom =True, top = False) 

#ax.set_xticks([0,10]) 
ax[0].set_xlabel('$t$', fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[0].set_ylabel(' $x$',fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[1].set_xlabel('$t$', fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[1].set_ylabel(' $x$',fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[2].set_xlabel('$t$', fontsize=8, math_fontfamily='cm', labelpad=0.5)
ax[2].set_ylabel(' $x$',fontsize=8, math_fontfamily='cm', labelpad=0.5)

#ax[0].plot(xt_bound[np.random.randint(0,2000,100),1],-5*np.ones((100,)),'kx')
#ax[0].plot(np.zeros((100,)),xt_bound[np.random.randint(0,2000,100),0],'kx')
#ax[0].plot(xt_bound[np.random.randint(0,2000,100),1],5*np.ones((100,)),'kx')


ax[0].tick_params(axis='x', labelsize=6)
ax[0].tick_params(axis='y', labelsize=6)
ax[0].set_title('Proposed',fontsize=8, math_fontfamily='cm')

ax[1].tick_params(axis='x', labelsize=6)
ax[1].tick_params(axis='y', labelsize=6)
ax[1].set_title('N-LAAF',fontsize=8, math_fontfamily='cm')

ax[2].tick_params(axis='x', labelsize=6)
ax[2].tick_params(axis='y', labelsize=6)
ax[2].set_title('tanh',fontsize=8, math_fontfamily='cm')

fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=None)


plt.savefig('2D_1_prediction_comparison.eps', format='eps',pad_inches=0, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

cmap = plt.cm.rainbow

img = ax.imshow(y_true.reshape(500,1000),vmin = -5,vmax = 5,cmap = cmap,extent=[0,10,5,-5],aspect = 0.75)

cbar = fig.colorbar(img, ax=ax,location = 'right',orientation = 'vertical', aspect = 20,pad = 0.05, extend = 'neither',shrink = 0.91)
cbar.ax.tick_params(labelsize=14,labelright = True, right = True) 

#ax.set_xticks([0,10]) 
ax.set_xlabel('$t$', fontsize=18, math_fontfamily='cm')
ax.set_ylabel(' $x$',fontsize=18, math_fontfamily='cm')

ax.margins(x = 100,y = 100)
np.random.RandomState(1234)
idx_plt = np.random.randint(0,np.shape(xt_bound)[0],200)
ax.plot(xt_bound[idx_plt,1],xt_bound[idx_plt,0],'kx',markersize = 6, label = 'Data (200 points)',clip_on = False)

ax.legend(loc = 'upper right',framealpha = 0.3,fontsize = 'large')
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
ax.set_title('$u(x,t)$',fontsize=18, math_fontfamily='cm')

plt.savefig('2D_1_true.eps', format='eps',pad_inches=0, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
