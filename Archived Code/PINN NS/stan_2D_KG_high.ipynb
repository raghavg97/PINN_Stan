# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from torch.nn.parameter import Parameter
import matplotlib as mpl

import numpy as np
import time
#from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io
from scipy.io import savemat
from scipy.io import loadmat

from smt.sampling_methods import LHS

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda:0

# %%
# def true_2D_1(xt): #True function for 2D_1 Klein Gordon Equation x \in [-50,50] , t \in [0,10]
#     x = xt[:,0].reshape(-1,1)
#     t = xt[:,1].reshape(-1,1)
#     y = x*np.cos(5*np.pi*t) + np.power(x*t,3)
#     return y.reshape(-1,1)

# %%
pi = np.pi
Re = 100
level = "high"
label = "NS_stan_" + level

x = np.linspace(0,1,101).reshape(-1,1)
y = np.linspace(0,1,101).reshape(-1,1)
t = np.linspace(0,1,101).reshape(-1,1)

X,Y,T = np.meshgrid(x,y,t)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xyt = np.hstack((X,Y,T))

# y_true = true_2D_1(xt)
# y_true_norm = np.linalg.norm(y_true,2)

#bound_pts_idx = ((X == -5) + (X == 5) + (T == 0)).reshape(-1,)

#xt_bound = xt[bound_pts_idx,:]
#y_bound = y_true[bound_pts_idx,:]


xyt_test_tensor = torch.from_numpy(xyt).float().to(device)


lb_xyt = xyt[0]
ub_xyt = xyt[-1]

# %%
def trainingdata(N_I,N_B,N_f,seed):
    '''Boundary Conditions''' 
    
    np.random.seed(seed)
    x_I = np.random.uniform(size = N_I).reshape(-1,1)
    y_I = np.random.uniform(size = N_I).reshape(-1,1)
    t_I = np.zeros((N_I,1))
    xyt_I = np.hstack((x_I,y_I,t_I))
    u_I = np.zeros((N_I,1))
    v_I = np.zeros((N_I,1))
    p_I = np.zeros((N_I,1))
    
    #Top
    x_BC1 = np.random.uniform(size = N_B).reshape(-1,1)
    y_BC1 = np.ones((N_B,1))
    t_BC1 = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_BC1 = np.hstack((x_BC1,y_BC1,t_BC1))
    u_BC1 = np.ones((N_B,1))
    v_BC1 = np.zeros((N_B,1))
    
    #Right
    x_BC2 = np.ones((N_B,1))
    y_BC2 = np.random.uniform(size = N_B).reshape(-1,1)
    t_BC2 = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_BC2 = np.hstack((x_BC2,y_BC2,t_BC2))
    u_BC2 = np.zeros((N_B,1))
    v_BC2 = np.zeros((N_B,1))

    #Bottom
    x_BC3 = np.random.uniform(size = N_B).reshape(-1,1)
    y_BC3 = np.zeros((N_B,1))
    t_BC3 = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_BC3 = np.hstack((x_BC3,y_BC3,t_BC3))
    u_BC3 = np.zeros((N_B,1))
    v_BC3 = np.zeros((N_B,1))
    
    #Left
    x_BC4 = np.zeros((N_B,1))
    y_BC4 = np.random.uniform(size = N_B).reshape(-1,1)
    t_BC4 = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_BC4 = np.hstack((x_BC4,y_BC4,t_BC4))
    u_BC4 = np.zeros((N_B,1))
    v_BC4 = np.zeros((N_B,1))
    
    
    xyt_BC = np.vstack((xyt_BC1,xyt_BC2,xyt_BC3,xyt_BC4))
    u_BC = np.vstack((u_BC1,u_BC2,u_BC3,u_BC4))
    v_BC = np.vstack((v_BC1,v_BC2,v_BC3,v_BC4))

    x_p = np.zeros((N_B,1))
    y_p = np.zeros((N_B,1))
    t_p = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_p = np.hstack((x_p,y_p,t_p))
    u_p = np.zeros((N_B,1))
    v_p = np.zeros((N_B,1))
    p_p = np.zeros((N_B,1))
    
    xyt_Ip = np.vstack((xyt_I,xyt_p))
    u_Ip = np.vstack((u_I,u_p))
    v_Ip = np.vstack((v_I,v_p))
    p_Ip = np.vstack((p_I,p_p))

    '''Collocation Points'''

    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,t)
    x01 = np.array([[0.0,1.0],[0.0,1.0],[0.0,1.0]])
    sampling = LHS(xlimits=x01,random_state =seed)
    samples = sampling(N_f)
    xyt_coll = lb_xyt + (ub_xyt - lb_xyt)*samples
    
    xyt_coll = np.vstack((xyt_coll, xyt_BC,xyt_I,xyt_p)) # append training points to collocation points 

    return xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip

# %%
class Sequentialmodel(nn.Module):
    
    def __init__(self,layers,beta_init):
        super().__init__() #call __init__ from parent class 
              
        'activation function'
        self.activation = nn.Tanh()

        'loss function'
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        'Initialise neural network as a list using nn.Modulelist'  
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)
            
        
        beta_mean = 1.0*torch.ones((50,len(layers)-2))
        beta_std = 0.01*torch.ones((50,len(layers)-2))
        
        self.beta = Parameter(torch.normal(beta_mean,beta_std))
        self.beta.requiresGrad = True

            
    'foward pass'
    def forward(self,xyt):
        if torch.is_tensor(xyt) != True:         
            xt = torch.from_numpy(xyt)                
        
        ubxyt = torch.from_numpy(ub_xyt).float().to(device)
        lbxyt = torch.from_numpy(lb_xyt).float().to(device)
    
                      
        #preprocessing input 
        xyt = 2.0*(xyt - lbxyt)/(ubxyt - lbxyt) - 1.0
        
        #convert to float
        a = xyt.float()
        
        for i in range(len(layers)-2):
            z = self.linears[i](a)
            z1 = self.activation(z)
            a = z1 + self.beta[:,i]*z*z1            
        
        a = self.linears[-1](a) 
         
        return a
                        
    def loss_BC(self,xyt_BC,u_BC,v_BC):
                
        uvp = self.forward(xyt_BC)
        
        loss_bc_u = self.loss_function(uvp[:,0:1],u_BC)
        loss_bc_v = self.loss_function(uvp[:,1:2],v_BC)
        
        # psi_p_pred = self.forward(torch.cat((x1,y1,t1),dim =1))
        # psi = psi_p_pred[:,0:1]
        # p_pred = psi_p_pred[:,1:2]
                
        return loss_bc_u + loss_bc_v
    
    def loss_Ip(self,xyt_Ip,u_Ip,v_Ip,p_Ip):
                
        uvp = self.forward(xyt_Ip)
        
        loss_ip_u = self.loss_function(uvp[:,0:1],u_Ip)
        loss_ip_v = self.loss_function(uvp[:,1:2],v_Ip)
        loss_ip_p = self.loss_function(uvp[:,2:3],p_Ip)
        
        # psi_p_pred = self.forward(torch.cat((x1,y1,t1),dim =1))
        # psi = psi_p_pred[:,0:1]
        # p_pred = psi_p_pred[:,1:2]
                
        return loss_ip_u + loss_ip_v+loss_ip_p
    
    def loss_PDE(self, xyt_coll, f_hat):
        
        g = xyt_coll.clone()             
        g.requires_grad = True
        uvp = self.forward(g) 
        
        u = uvp[:,0:1]
        v = uvp[:,1:2]
        p = uvp[:,2:3]
        
        
        #u
        u_xyt = autograd.grad(u,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
    
        u_xx_yy_tt = autograd.grad(u_xyt,g,torch.ones(xyt_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        du_dx = u_xyt[:,[0]]
        du_dy = u_xyt[:,[1]]
        du_dt = u_xyt[:,[2]]
        
        d2u_dx2 = u_xx_yy_tt[:,[0]]
        d2u_dy2 = u_xx_yy_tt[:,[1]]
        
        #v
        v_xyt = autograd.grad(v,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]

        v_xx_yy_tt = autograd.grad(v_xyt,g,torch.ones(xyt_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        dv_dx = v_xyt[:,[0]]
        dv_dy = v_xyt[:,[1]]
        dv_dt = v_xyt[:,[2]]
        
        d2v_dx2 = v_xx_yy_tt[:,[0]]
        d2v_dy2 = v_xx_yy_tt[:,[1]]
        
        #p
        p_xyt = autograd.grad(p,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]

        dp_dx = p_xyt[:,[0]]
        dp_dy = p_xyt[:,[1]]
    
        
        
        f_u = du_dt + u*du_dx + v*du_dy + dp_dx - (d2u_dx2 + d2u_dy2)/Re
        f_v = dv_dt + u*dv_dx + v*dv_dy + dp_dy - (d2v_dx2 + d2v_dy2)/Re
        
        
        loss_f_u = self.loss_function(f_u,f_hat)
        loss_f_v = self.loss_function(f_v,f_hat)
                
        return loss_f_u + loss_f_v
    
    
    def loss_NBC(self,xyt_coll,N_hat):
        g = xyt_coll.clone()             
        g.requires_grad = True
        uvp = self.forward(g)
        
        u = uvp[:,0:1]
        v = uvp[:,1:2]
        
        u_xyt = autograd.grad(u,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        v_xyt = autograd.grad(v,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        
        du_dx = u_xyt[:,[0]]
        dv_dy = v_xyt[:,[1]]
        
        loss_nbc = self.loss_function(du_dx + dv_dy, N_hat)
                
        return loss_nbc
    
    
    def loss(self,xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat):

        loss_BC = self.loss_BC(xyt_BC,u_BC,v_BC)
        loss_Ip = self.loss_Ip(xyt_Ip,u_Ip,v_Ip,p_Ip)
        loss_NBC = self.loss_NBC(xyt_coll,N_hat)
        loss_f = self.loss_PDE(xyt_coll,f_hat)
        
        loss_val = loss_BC + loss_f + loss_NBC +loss_Ip
        
        return loss_val
         
    'test neural network'
    def test(self):
        y_pred = self.forward(xt_test_tensor)
        y_pred = y_pred.cpu().detach().numpy()
   
        return y_pred
    
    def test_loss(self):
        # y_pred = self.test()
        
        # test_mse = np.mean(np.square(y_pred.reshape(-1,1) - y_true.reshape(-1,1)))
        # test_re = np.linalg.norm(y_pred.reshape(-1,1) - y_true.reshape(-1,1),2)/y_true_norm
        test_mse = 0
        test_re = 0
        
        return test_mse, test_re

# %%
def data_update(loss_np):
    train_loss.append(loss_np)
    beta_val.append(PINN.beta.cpu().detach().numpy())
    
    test_mse, test_re = PINN.test_loss()
    test_mse_loss.append(test_mse)
    test_re_loss.append(test_re)

# %%
def train_step(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat,seed):
    
    def closure():
        optimizer.zero_grad()
        loss = PINN.loss(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat)
        loss.backward()
        #print(loss.cpu().detach().numpy())
        return loss

    optimizer.step(closure)

# %%
def train_model(max_iter,rep): 
    print(rep) 
    torch.manual_seed(rep*9)
    start_time = time.time() 
    thresh_flag = 0

    xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip = trainingdata(N_I,N_B,N_f,rep*11)
    xyt_coll = torch.from_numpy(xyt_coll).float().to(device)
    xyt_BC = torch.from_numpy(xyt_BC).float().to(device)
    u_BC = torch.from_numpy(u_BC).float().to(device)
    v_BC = torch.from_numpy(v_BC).float().to(device)
    
    xyt_Ip = torch.from_numpy(xyt_Ip).float().to(device)
    u_Ip = torch.from_numpy(u_Ip).float().to(device)
    v_Ip = torch.from_numpy(v_Ip).float().to(device)
    p_Ip = torch.from_numpy(p_Ip).float().to(device)
    
    f_hat = torch.zeros(xyt_coll.shape[0],1).to(device)
    N_hat = torch.zeros(xyt_coll.shape[0],1).to(device)
    
    loss_np = PINN.loss(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat).cpu().detach().numpy()
    data_update(loss_np)
    for i in range(max_iter):
        if(np.isnan(loss_np) == False):
            train_step(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat,i)
            loss_np = PINN.loss(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat).cpu().detach().numpy()
        

        data_update(loss_np)
        
        print(i,"Train Loss",train_loss[-1],"Test MSE",test_mse_loss[-1],"Test RE",test_re_loss[-1])   
        
      

    elapsed_time[rep] = time.time() - start_time  
    print('Training time: %.2f' % (elapsed_time[rep]))

# %%
max_reps = 1 #10
max_iter = 500 #200

train_loss_full = []
test_mse_full = []
test_re_full = []
beta_full = []
elapsed_time= np.zeros((max_reps,1))
time_threshold = np.empty((max_reps,1))
time_threshold[:] = np.nan
epoch_threshold = max_iter*np.ones((max_reps,1))

beta_init = 0

N_I = 2000  #Total number of data points for 'y'
N_B = 2000
N_f = 10000 #Total number of collocation points

for reps in range(max_reps):
    print(label)
    print(reps)
    train_loss = []
    test_mse_loss = []
    test_re_loss = []
    beta_val = []

    torch.manual_seed(reps*36)

    layers = np.array([3,50,50,50,50,3]) #9 hidden layers
    # layers = np.array([2,50,50,50,50,50,50,50,1])

    PINN = Sequentialmodel(layers,beta_init)

    PINN.to(device)

    'Neural Network Summary'
    print(PINN)

    params = list(PINN.parameters())


    optimizer = torch.optim.LBFGS(PINN.parameters(), lr=1, 
                            max_iter = 20, 
                            max_eval = 30, 
                            tolerance_grad = 1e-8, 
                            tolerance_change = 1e-8, 
                            history_size = 100, 
                            line_search_fn = 'strong_wolfe')




    nan_flag = train_model(max_iter,reps)



    torch.save(PINN.state_dict(),label+'_'+str(reps)+'.pt')
    train_loss_full.append(train_loss)
    test_mse_full.append(test_mse_loss)
    test_re_full.append(test_re_loss)
    #elapsed_time[reps] = time.time() - start_time
    beta_full.append(beta_val)


  #print('Training time: %.2f' % (elapsed_time[reps]))

mdic = {"train_loss": train_loss_full,"test_mse_loss": test_mse_full,"test_re_loss": test_re_full,"Time": elapsed_time, "beta": beta_full, "label": label,"Thresh Time": time_threshold,"Thresh epoch": epoch_threshold}
savemat(label+'.mat', mdic)
# Out:
# NS_stan_high
# 0
# Sequentialmodel(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears): ModuleList(
#     (0): Linear(in_features=3, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): Linear(in_features=50, out_features=50, bias=True)
#     (4): Linear(in_features=50, out_features=3, bias=True)
#   )
# )
# 0
# 0 Train Loss 0.08603969 Test MSE 0 Test RE 0
# 1 Train Loss 0.04983189 Test MSE 0 Test RE 0
# 2 Train Loss 0.029015135 Test MSE 0 Test RE 0
# 3 Train Loss 0.024466563 Test MSE 0 Test RE 0
# 4 Train Loss 0.022890786 Test MSE 0 Test RE 0
# 5 Train Loss 0.021737412 Test MSE 0 Test RE 0
# 6 Train Loss 0.02078842 Test MSE 0 Test RE 0
# 7 Train Loss 0.020129146 Test MSE 0 Test RE 0
# 8 Train Loss 0.01941903 Test MSE 0 Test RE 0
# 9 Train Loss 0.018742539 Test MSE 0 Test RE 0
# 10 Train Loss 0.018283535 Test MSE 0 Test RE 0
# 11 Train Loss 0.017862186 Test MSE 0 Test RE 0
# 12 Train Loss 0.017467726 Test MSE 0 Test RE 0
# 13 Train Loss 0.017112112 Test MSE 0 Test RE 0
# 14 Train Loss 0.01687136 Test MSE 0 Test RE 0
# 15 Train Loss 0.0166578 Test MSE 0 Test RE 0
# 16 Train Loss 0.01648138 Test MSE 0 Test RE 0
# 17 Train Loss 0.016290585 Test MSE 0 Test RE 0
# 18 Train Loss 0.016110143 Test MSE 0 Test RE 0
# 19 Train Loss 0.015970271 Test MSE 0 Test RE 0
# 20 Train Loss 0.015816309 Test MSE 0 Test RE 0
# 21 Train Loss 0.01563783 Test MSE 0 Test RE 0
# 22 Train Loss 0.015467797 Test MSE 0 Test RE 0
# 23 Train Loss 0.015324539 Test MSE 0 Test RE 0
# 24 Train Loss 0.015203666 Test MSE 0 Test RE 0
# 25 Train Loss 0.015089415 Test MSE 0 Test RE 0
# 26 Train Loss 0.014965964 Test MSE 0 Test RE 0
# 27 Train Loss 0.014858688 Test MSE 0 Test RE 0
# 28 Train Loss 0.014760799 Test MSE 0 Test RE 0
# 29 Train Loss 0.0146732405 Test MSE 0 Test RE 0
# 30 Train Loss 0.014579727 Test MSE 0 Test RE 0
# 31 Train Loss 0.014486308 Test MSE 0 Test RE 0
# 32 Train Loss 0.014378046 Test MSE 0 Test RE 0
# 33 Train Loss 0.014294908 Test MSE 0 Test RE 0
# 34 Train Loss 0.014208558 Test MSE 0 Test RE 0
# 35 Train Loss 0.014138883 Test MSE 0 Test RE 0
# 36 Train Loss 0.014043633 Test MSE 0 Test RE 0
# 37 Train Loss 0.013958888 Test MSE 0 Test RE 0
# 38 Train Loss 0.013867231 Test MSE 0 Test RE 0
# 39 Train Loss 0.013796649 Test MSE 0 Test RE 0
# 40 Train Loss 0.013733875 Test MSE 0 Test RE 0
# 41 Train Loss 0.013665729 Test MSE 0 Test RE 0
# 42 Train Loss 0.0136036975 Test MSE 0 Test RE 0
# 43 Train Loss 0.013523061 Test MSE 0 Test RE 0
# 44 Train Loss 0.013448291 Test MSE 0 Test RE 0
# 45 Train Loss 0.01335641 Test MSE 0 Test RE 0
# 46 Train Loss 0.013260934 Test MSE 0 Test RE 0
# 47 Train Loss 0.013168173 Test MSE 0 Test RE 0
# 48 Train Loss 0.013079963 Test MSE 0 Test RE 0
# 49 Train Loss 0.012986562 Test MSE 0 Test RE 0
# 50 Train Loss 0.012890212 Test MSE 0 Test RE 0
# 51 Train Loss 0.012794144 Test MSE 0 Test RE 0
# 52 Train Loss 0.012696918 Test MSE 0 Test RE 0
# 53 Train Loss 0.01257404 Test MSE 0 Test RE 0
# 54 Train Loss 0.012486162 Test MSE 0 Test RE 0
# 55 Train Loss 0.012365418 Test MSE 0 Test RE 0
# 56 Train Loss 0.0122286305 Test MSE 0 Test RE 0
# 57 Train Loss 0.012103728 Test MSE 0 Test RE 0
# 58 Train Loss 0.011975692 Test MSE 0 Test RE 0
# 59 Train Loss 0.011848547 Test MSE 0 Test RE 0
# 60 Train Loss 0.011726342 Test MSE 0 Test RE 0
# 61 Train Loss 0.011589679 Test MSE 0 Test RE 0
# 62 Train Loss 0.011457243 Test MSE 0 Test RE 0
# 63 Train Loss 0.011318189 Test MSE 0 Test RE 0
# 64 Train Loss 0.011187754 Test MSE 0 Test RE 0
# 65 Train Loss 0.011081506 Test MSE 0 Test RE 0
# 66 Train Loss 0.0109737795 Test MSE 0 Test RE 0
# 67 Train Loss 0.010862042 Test MSE 0 Test RE 0
# 68 Train Loss 0.0107535375 Test MSE 0 Test RE 0
# 69 Train Loss 0.010647312 Test MSE 0 Test RE 0
# 70 Train Loss 0.010567156 Test MSE 0 Test RE 0
# 71 Train Loss 0.010473202 Test MSE 0 Test RE 0
# 72 Train Loss 0.0103942845 Test MSE 0 Test RE 0
# 73 Train Loss 0.010324575 Test MSE 0 Test RE 0
# 74 Train Loss 0.010244897 Test MSE 0 Test RE 0
# 75 Train Loss 0.010167768 Test MSE 0 Test RE 0
# 76 Train Loss 0.010103823 Test MSE 0 Test RE 0
# 77 Train Loss 0.010031969 Test MSE 0 Test RE 0
# 78 Train Loss 0.009963801 Test MSE 0 Test RE 0
# 79 Train Loss 0.009905274 Test MSE 0 Test RE 0
# 80 Train Loss 0.009844588 Test MSE 0 Test RE 0
# 81 Train Loss 0.009781055 Test MSE 0 Test RE 0
# 82 Train Loss 0.009722907 Test MSE 0 Test RE 0
# 83 Train Loss 0.00966937 Test MSE 0 Test RE 0
# 84 Train Loss 0.009614319 Test MSE 0 Test RE 0
# 85 Train Loss 0.0095576905 Test MSE 0 Test RE 0
# 86 Train Loss 0.0095099835 Test MSE 0 Test RE 0
# 87 Train Loss 0.0094616655 Test MSE 0 Test RE 0
# 88 Train Loss 0.009412844 Test MSE 0 Test RE 0
# 89 Train Loss 0.009361189 Test MSE 0 Test RE 0
# 90 Train Loss 0.009316202 Test MSE 0 Test RE 0
# 91 Train Loss 0.009270237 Test MSE 0 Test RE 0
# 92 Train Loss 0.009214719 Test MSE 0 Test RE 0
# 93 Train Loss 0.009160873 Test MSE 0 Test RE 0
# 94 Train Loss 0.009113104 Test MSE 0 Test RE 0
# 95 Train Loss 0.009076196 Test MSE 0 Test RE 0
# 96 Train Loss 0.0090313405 Test MSE 0 Test RE 0
# 97 Train Loss 0.008976668 Test MSE 0 Test RE 0
# 98 Train Loss 0.008936951 Test MSE 0 Test RE 0
# 99 Train Loss 0.008889974 Test MSE 0 Test RE 0
# 100 Train Loss 0.008857317 Test MSE 0 Test RE 0
# 101 Train Loss 0.00881945 Test MSE 0 Test RE 0
# 102 Train Loss 0.00878041 Test MSE 0 Test RE 0
# 103 Train Loss 0.00874519 Test MSE 0 Test RE 0
# 104 Train Loss 0.008711321 Test MSE 0 Test RE 0
# 105 Train Loss 0.008680506 Test MSE 0 Test RE 0
# 106 Train Loss 0.008647297 Test MSE 0 Test RE 0
# 107 Train Loss 0.008607792 Test MSE 0 Test RE 0
# 108 Train Loss 0.00857045 Test MSE 0 Test RE 0
# 109 Train Loss 0.008534227 Test MSE 0 Test RE 0
# 110 Train Loss 0.008502745 Test MSE 0 Test RE 0
# 111 Train Loss 0.008469206 Test MSE 0 Test RE 0
# 112 Train Loss 0.008435899 Test MSE 0 Test RE 0
# 113 Train Loss 0.008402443 Test MSE 0 Test RE 0
# 114 Train Loss 0.008367509 Test MSE 0 Test RE 0
# 115 Train Loss 0.008340211 Test MSE 0 Test RE 0
# 116 Train Loss 0.008304812 Test MSE 0 Test RE 0
# 117 Train Loss 0.008270599 Test MSE 0 Test RE 0
# 118 Train Loss 0.008239036 Test MSE 0 Test RE 0
# 119 Train Loss 0.008210999 Test MSE 0 Test RE 0
# 120 Train Loss 0.008182957 Test MSE 0 Test RE 0
# 121 Train Loss 0.008153123 Test MSE 0 Test RE 0
# 122 Train Loss 0.008123992 Test MSE 0 Test RE 0
# 123 Train Loss 0.008100042 Test MSE 0 Test RE 0
# 124 Train Loss 0.008078209 Test MSE 0 Test RE 0
# 125 Train Loss 0.008052682 Test MSE 0 Test RE 0
# 126 Train Loss 0.0080299005 Test MSE 0 Test RE 0
# 127 Train Loss 0.008002688 Test MSE 0 Test RE 0
# 128 Train Loss 0.007976445 Test MSE 0 Test RE 0
# 129 Train Loss 0.007949842 Test MSE 0 Test RE 0
# 130 Train Loss 0.007919748 Test MSE 0 Test RE 0
# 131 Train Loss 0.00789798 Test MSE 0 Test RE 0
# 132 Train Loss 0.007870403 Test MSE 0 Test RE 0
# 133 Train Loss 0.007850843 Test MSE 0 Test RE 0
# 134 Train Loss 0.00782791 Test MSE 0 Test RE 0
# 135 Train Loss 0.007807798 Test MSE 0 Test RE 0
# 136 Train Loss 0.0077854167 Test MSE 0 Test RE 0
# 137 Train Loss 0.0077641876 Test MSE 0 Test RE 0
# 138 Train Loss 0.007733698 Test MSE 0 Test RE 0
# 139 Train Loss 0.0077127037 Test MSE 0 Test RE 0
# 140 Train Loss 0.007688485 Test MSE 0 Test RE 0
# 141 Train Loss 0.007665819 Test MSE 0 Test RE 0
# 142 Train Loss 0.0076463185 Test MSE 0 Test RE 0
# 143 Train Loss 0.0076214457 Test MSE 0 Test RE 0
# 144 Train Loss 0.007599657 Test MSE 0 Test RE 0
# 145 Train Loss 0.0075783595 Test MSE 0 Test RE 0
# 146 Train Loss 0.007554311 Test MSE 0 Test RE 0
# 147 Train Loss 0.0075353347 Test MSE 0 Test RE 0
# 148 Train Loss 0.0075120404 Test MSE 0 Test RE 0
# 149 Train Loss 0.007488749 Test MSE 0 Test RE 0
# 150 Train Loss 0.0074625025 Test MSE 0 Test RE 0
# 151 Train Loss 0.0074390178 Test MSE 0 Test RE 0
# 152 Train Loss 0.007414636 Test MSE 0 Test RE 0
# 153 Train Loss 0.0073911743 Test MSE 0 Test RE 0
# 154 Train Loss 0.0073698726 Test MSE 0 Test RE 0
# 155 Train Loss 0.0073517133 Test MSE 0 Test RE 0
# 156 Train Loss 0.007328198 Test MSE 0 Test RE 0
# 157 Train Loss 0.0073107556 Test MSE 0 Test RE 0
# 158 Train Loss 0.007291544 Test MSE 0 Test RE 0
# 159 Train Loss 0.007272286 Test MSE 0 Test RE 0
# 160 Train Loss 0.0072481334 Test MSE 0 Test RE 0
# 161 Train Loss 0.007226237 Test MSE 0 Test RE 0
# 162 Train Loss 0.0072113248 Test MSE 0 Test RE 0
# 163 Train Loss 0.007194065 Test MSE 0 Test RE 0
# 164 Train Loss 0.007173763 Test MSE 0 Test RE 0
# 165 Train Loss 0.0071527185 Test MSE 0 Test RE 0
# 166 Train Loss 0.0071316706 Test MSE 0 Test RE 0
# 167 Train Loss 0.0071144495 Test MSE 0 Test RE 0
# 168 Train Loss 0.007099685 Test MSE 0 Test RE 0
# 169 Train Loss 0.007081665 Test MSE 0 Test RE 0
# 170 Train Loss 0.0070640985 Test MSE 0 Test RE 0
# 171 Train Loss 0.0070460746 Test MSE 0 Test RE 0
# 172 Train Loss 0.0070280097 Test MSE 0 Test RE 0
# 173 Train Loss 0.0070112655 Test MSE 0 Test RE 0
# 174 Train Loss 0.006995345 Test MSE 0 Test RE 0
# 175 Train Loss 0.0069776843 Test MSE 0 Test RE 0
# 176 Train Loss 0.0069593773 Test MSE 0 Test RE 0
# 177 Train Loss 0.006940869 Test MSE 0 Test RE 0
# 178 Train Loss 0.006926513 Test MSE 0 Test RE 0
# 179 Train Loss 0.00690785 Test MSE 0 Test RE 0
# 180 Train Loss 0.006888847 Test MSE 0 Test RE 0
# 181 Train Loss 0.0068722027 Test MSE 0 Test RE 0
# 182 Train Loss 0.0068537244 Test MSE 0 Test RE 0
# 183 Train Loss 0.00683893 Test MSE 0 Test RE 0
# 184 Train Loss 0.0068250527 Test MSE 0 Test RE 0
# 185 Train Loss 0.006807893 Test MSE 0 Test RE 0
# 186 Train Loss 0.0067873243 Test MSE 0 Test RE 0
# 187 Train Loss 0.006768356 Test MSE 0 Test RE 0
# 188 Train Loss 0.0067544035 Test MSE 0 Test RE 0
# 189 Train Loss 0.006738158 Test MSE 0 Test RE 0
# 190 Train Loss 0.0067226924 Test MSE 0 Test RE 0
# 191 Train Loss 0.0067071533 Test MSE 0 Test RE 0
# 192 Train Loss 0.0066914456 Test MSE 0 Test RE 0
# 193 Train Loss 0.0066739107 Test MSE 0 Test RE 0
# 194 Train Loss 0.0066578835 Test MSE 0 Test RE 0
# 195 Train Loss 0.0066439942 Test MSE 0 Test RE 0
# 196 Train Loss 0.006629036 Test MSE 0 Test RE 0
# 197 Train Loss 0.0066096056 Test MSE 0 Test RE 0
# 198 Train Loss 0.006591712 Test MSE 0 Test RE 0
# 199 Train Loss 0.0065795365 Test MSE 0 Test RE 0
# 200 Train Loss 0.0065648668 Test MSE 0 Test RE 0
# 201 Train Loss 0.006549172 Test MSE 0 Test RE 0
# 202 Train Loss 0.0065335976 Test MSE 0 Test RE 0
# 203 Train Loss 0.0065175397 Test MSE 0 Test RE 0
# 204 Train Loss 0.0065036085 Test MSE 0 Test RE 0
# 205 Train Loss 0.006489077 Test MSE 0 Test RE 0
# 206 Train Loss 0.006474587 Test MSE 0 Test RE 0
# 207 Train Loss 0.0064579905 Test MSE 0 Test RE 0
# 208 Train Loss 0.0064426586 Test MSE 0 Test RE 0
# 209 Train Loss 0.00642943 Test MSE 0 Test RE 0
# 210 Train Loss 0.0064143073 Test MSE 0 Test RE 0
# 211 Train Loss 0.006397325 Test MSE 0 Test RE 0
# 212 Train Loss 0.006384694 Test MSE 0 Test RE 0
# 213 Train Loss 0.00637143 Test MSE 0 Test RE 0
# 214 Train Loss 0.0063576964 Test MSE 0 Test RE 0
# 215 Train Loss 0.0063442932 Test MSE 0 Test RE 0
# 216 Train Loss 0.006332023 Test MSE 0 Test RE 0
# 217 Train Loss 0.0063129133 Test MSE 0 Test RE 0
# 218 Train Loss 0.006294062 Test MSE 0 Test RE 0
# 219 Train Loss 0.006277323 Test MSE 0 Test RE 0
# 220 Train Loss 0.0062628877 Test MSE 0 Test RE 0
# 221 Train Loss 0.0062444434 Test MSE 0 Test RE 0
# 222 Train Loss 0.006226676 Test MSE 0 Test RE 0
# 223 Train Loss 0.0062111127 Test MSE 0 Test RE 0
# 224 Train Loss 0.006196723 Test MSE 0 Test RE 0
# 225 Train Loss 0.0061846036 Test MSE 0 Test RE 0
# 226 Train Loss 0.0061718486 Test MSE 0 Test RE 0
# 227 Train Loss 0.0061584995 Test MSE 0 Test RE 0
# 228 Train Loss 0.006146197 Test MSE 0 Test RE 0
# 229 Train Loss 0.006133168 Test MSE 0 Test RE 0
# 230 Train Loss 0.006122981 Test MSE 0 Test RE 0
# 231 Train Loss 0.0061117676 Test MSE 0 Test RE 0
# 232 Train Loss 0.0060965936 Test MSE 0 Test RE 0
# 233 Train Loss 0.0060812803 Test MSE 0 Test RE 0
# 234 Train Loss 0.0060669896 Test MSE 0 Test RE 0
# 235 Train Loss 0.00605204 Test MSE 0 Test RE 0
# 236 Train Loss 0.006035417 Test MSE 0 Test RE 0
# 237 Train Loss 0.0060170693 Test MSE 0 Test RE 0
# 238 Train Loss 0.006002267 Test MSE 0 Test RE 0
# 239 Train Loss 0.0059876344 Test MSE 0 Test RE 0
# 240 Train Loss 0.0059735067 Test MSE 0 Test RE 0
# 241 Train Loss 0.005959186 Test MSE 0 Test RE 0
# 242 Train Loss 0.00594516 Test MSE 0 Test RE 0
# 243 Train Loss 0.005933857 Test MSE 0 Test RE 0
# 244 Train Loss 0.005920917 Test MSE 0 Test RE 0
# 245 Train Loss 0.0059051085 Test MSE 0 Test RE 0
# 246 Train Loss 0.005890539 Test MSE 0 Test RE 0
# 247 Train Loss 0.0058765337 Test MSE 0 Test RE 0
# 248 Train Loss 0.0058655925 Test MSE 0 Test RE 0
# 249 Train Loss 0.0058531994 Test MSE 0 Test RE 0
# 250 Train Loss 0.0058416533 Test MSE 0 Test RE 0
# 251 Train Loss 0.005829863 Test MSE 0 Test RE 0
# 252 Train Loss 0.005818769 Test MSE 0 Test RE 0
# 253 Train Loss 0.0058045355 Test MSE 0 Test RE 0
# 254 Train Loss 0.00579011 Test MSE 0 Test RE 0
# 255 Train Loss 0.0057784384 Test MSE 0 Test RE 0
# 256 Train Loss 0.0057671866 Test MSE 0 Test RE 0
# 257 Train Loss 0.005756634 Test MSE 0 Test RE 0
# 258 Train Loss 0.0057473625 Test MSE 0 Test RE 0
# 259 Train Loss 0.005735851 Test MSE 0 Test RE 0
# 260 Train Loss 0.005726023 Test MSE 0 Test RE 0
# 261 Train Loss 0.0057151625 Test MSE 0 Test RE 0
# 262 Train Loss 0.0057039424 Test MSE 0 Test RE 0
# 263 Train Loss 0.005692182 Test MSE 0 Test RE 0
# 264 Train Loss 0.0056823315 Test MSE 0 Test RE 0
# 265 Train Loss 0.005674054 Test MSE 0 Test RE 0
# 266 Train Loss 0.0056641377 Test MSE 0 Test RE 0
# 267 Train Loss 0.0056543853 Test MSE 0 Test RE 0
# 268 Train Loss 0.0056427633 Test MSE 0 Test RE 0
# 269 Train Loss 0.0056335637 Test MSE 0 Test RE 0
# 270 Train Loss 0.005624392 Test MSE 0 Test RE 0
# 271 Train Loss 0.00561219 Test MSE 0 Test RE 0
# 272 Train Loss 0.0055999183 Test MSE 0 Test RE 0
# 273 Train Loss 0.005589389 Test MSE 0 Test RE 0
# 274 Train Loss 0.0055815005 Test MSE 0 Test RE 0
# 275 Train Loss 0.005570546 Test MSE 0 Test RE 0
# 276 Train Loss 0.0055602845 Test MSE 0 Test RE 0
# 277 Train Loss 0.005551063 Test MSE 0 Test RE 0
# 278 Train Loss 0.0055401498 Test MSE 0 Test RE 0
# 279 Train Loss 0.0055308165 Test MSE 0 Test RE 0
# 280 Train Loss 0.0055207633 Test MSE 0 Test RE 0
# 281 Train Loss 0.005513683 Test MSE 0 Test RE 0
# 282 Train Loss 0.0055055255 Test MSE 0 Test RE 0
# 283 Train Loss 0.0054964274 Test MSE 0 Test RE 0
# 284 Train Loss 0.005486925 Test MSE 0 Test RE 0
# 285 Train Loss 0.0054764794 Test MSE 0 Test RE 0
# 286 Train Loss 0.0054671885 Test MSE 0 Test RE 0
# 287 Train Loss 0.0054579317 Test MSE 0 Test RE 0
# 288 Train Loss 0.00544717 Test MSE 0 Test RE 0
# 289 Train Loss 0.005435689 Test MSE 0 Test RE 0
# 290 Train Loss 0.0054256488 Test MSE 0 Test RE 0
# 291 Train Loss 0.0054133707 Test MSE 0 Test RE 0
# 292 Train Loss 0.0054034158 Test MSE 0 Test RE 0
# 293 Train Loss 0.0053949235 Test MSE 0 Test RE 0
# 294 Train Loss 0.005385482 Test MSE 0 Test RE 0
# 295 Train Loss 0.005375956 Test MSE 0 Test RE 0
# 296 Train Loss 0.005364539 Test MSE 0 Test RE 0
# 297 Train Loss 0.005354449 Test MSE 0 Test RE 0
# 298 Train Loss 0.005344567 Test MSE 0 Test RE 0
# 299 Train Loss 0.005332447 Test MSE 0 Test RE 0
# 300 Train Loss 0.0053228834 Test MSE 0 Test RE 0
# 301 Train Loss 0.0053120335 Test MSE 0 Test RE 0
# 302 Train Loss 0.0053031133 Test MSE 0 Test RE 0
# 303 Train Loss 0.0052941637 Test MSE 0 Test RE 0
# 304 Train Loss 0.0052846116 Test MSE 0 Test RE 0
# 305 Train Loss 0.005275412 Test MSE 0 Test RE 0
# 306 Train Loss 0.005265497 Test MSE 0 Test RE 0
# 307 Train Loss 0.005256031 Test MSE 0 Test RE 0
# 308 Train Loss 0.005249006 Test MSE 0 Test RE 0
# 309 Train Loss 0.0052412665 Test MSE 0 Test RE 0
# 310 Train Loss 0.005232123 Test MSE 0 Test RE 0
# 311 Train Loss 0.0052228356 Test MSE 0 Test RE 0
# 312 Train Loss 0.0052118273 Test MSE 0 Test RE 0
# 313 Train Loss 0.0052032834 Test MSE 0 Test RE 0
# 314 Train Loss 0.0051950943 Test MSE 0 Test RE 0
# 315 Train Loss 0.005184954 Test MSE 0 Test RE 0
# 316 Train Loss 0.005176058 Test MSE 0 Test RE 0
# 317 Train Loss 0.005168995 Test MSE 0 Test RE 0
# 318 Train Loss 0.0051609706 Test MSE 0 Test RE 0
# 319 Train Loss 0.0051526646 Test MSE 0 Test RE 0
# 320 Train Loss 0.005145212 Test MSE 0 Test RE 0
# 321 Train Loss 0.005137499 Test MSE 0 Test RE 0
# 322 Train Loss 0.0051297173 Test MSE 0 Test RE 0
# 323 Train Loss 0.0051217927 Test MSE 0 Test RE 0
# 324 Train Loss 0.0051124054 Test MSE 0 Test RE 0
# 325 Train Loss 0.0051034633 Test MSE 0 Test RE 0
# 326 Train Loss 0.0050944686 Test MSE 0 Test RE 0
# 327 Train Loss 0.0050861016 Test MSE 0 Test RE 0
# 328 Train Loss 0.005077393 Test MSE 0 Test RE 0
# 329 Train Loss 0.0050687497 Test MSE 0 Test RE 0
# 330 Train Loss 0.005061652 Test MSE 0 Test RE 0
# 331 Train Loss 0.0050527137 Test MSE 0 Test RE 0
# 332 Train Loss 0.0050443676 Test MSE 0 Test RE 0
# 333 Train Loss 0.005034233 Test MSE 0 Test RE 0
# 334 Train Loss 0.0050255237 Test MSE 0 Test RE 0
# 335 Train Loss 0.0050163805 Test MSE 0 Test RE 0
# 336 Train Loss 0.005007206 Test MSE 0 Test RE 0
# 337 Train Loss 0.004998237 Test MSE 0 Test RE 0
# 338 Train Loss 0.004988295 Test MSE 0 Test RE 0
# 339 Train Loss 0.0049794116 Test MSE 0 Test RE 0
# 340 Train Loss 0.004970258 Test MSE 0 Test RE 0
# 341 Train Loss 0.0049615363 Test MSE 0 Test RE 0
# 342 Train Loss 0.004952701 Test MSE 0 Test RE 0
# 343 Train Loss 0.004943691 Test MSE 0 Test RE 0
# 344 Train Loss 0.004934314 Test MSE 0 Test RE 0
# 345 Train Loss 0.0049241567 Test MSE 0 Test RE 0
# 346 Train Loss 0.0049149645 Test MSE 0 Test RE 0
# 347 Train Loss 0.004906766 Test MSE 0 Test RE 0
# 348 Train Loss 0.0048975945 Test MSE 0 Test RE 0
# 349 Train Loss 0.0048891194 Test MSE 0 Test RE 0
# 350 Train Loss 0.004881154 Test MSE 0 Test RE 0
# 351 Train Loss 0.0048727645 Test MSE 0 Test RE 0
# 352 Train Loss 0.0048650545 Test MSE 0 Test RE 0
# 353 Train Loss 0.004857466 Test MSE 0 Test RE 0
# 354 Train Loss 0.0048487694 Test MSE 0 Test RE 0
# 355 Train Loss 0.0048415046 Test MSE 0 Test RE 0
# 356 Train Loss 0.004831003 Test MSE 0 Test RE 0
# 357 Train Loss 0.004822682 Test MSE 0 Test RE 0
# 358 Train Loss 0.004815394 Test MSE 0 Test RE 0
# 359 Train Loss 0.0048062634 Test MSE 0 Test RE 0
# 360 Train Loss 0.0047988533 Test MSE 0 Test RE 0
# 361 Train Loss 0.0047921957 Test MSE 0 Test RE 0
# 362 Train Loss 0.004785407 Test MSE 0 Test RE 0
# 363 Train Loss 0.004778558 Test MSE 0 Test RE 0
# 364 Train Loss 0.0047709784 Test MSE 0 Test RE 0
# 365 Train Loss 0.004763605 Test MSE 0 Test RE 0
# 366 Train Loss 0.0047565633 Test MSE 0 Test RE 0
# 367 Train Loss 0.004749535 Test MSE 0 Test RE 0
# 368 Train Loss 0.0047435123 Test MSE 0 Test RE 0
# 369 Train Loss 0.004734765 Test MSE 0 Test RE 0
# 370 Train Loss 0.004725746 Test MSE 0 Test RE 0
# 371 Train Loss 0.0047176774 Test MSE 0 Test RE 0
# 372 Train Loss 0.004710428 Test MSE 0 Test RE 0
# 373 Train Loss 0.00470352 Test MSE 0 Test RE 0
# 374 Train Loss 0.0046947827 Test MSE 0 Test RE 0
# 375 Train Loss 0.004686166 Test MSE 0 Test RE 0
# 376 Train Loss 0.004678676 Test MSE 0 Test RE 0
# 377 Train Loss 0.004670514 Test MSE 0 Test RE 0
# 378 Train Loss 0.004661255 Test MSE 0 Test RE 0
# 379 Train Loss 0.0046545123 Test MSE 0 Test RE 0
# 380 Train Loss 0.004646812 Test MSE 0 Test RE 0
# 381 Train Loss 0.0046402495 Test MSE 0 Test RE 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27642/3251968150.py in <module>
#      51
#      52
# ---> 53     nan_flag = train_model(max_iter,reps)
#      54
#      55
#
# /tmp/ipykernel_27642/3221792313.py in train_model(max_iter, rep)
#      23     for i in range(max_iter):
#      24         if(np.isnan(loss_np) == False):
# ---> 25             train_step(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat,i)
#      26             loss_np = PINN.loss(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat).cpu().detach().numpy()
#      27
#
# /tmp/ipykernel_27642/2996678893.py in train_step(xyt_coll, xyt_BC, u_BC, v_BC, xyt_Ip, u_Ip, v_Ip, p_Ip, f_hat, N_hat, seed)
#       8         return loss
#       9
# ---> 10     optimizer.step(closure)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/lbfgs.py in step(self, closure)
#     380                 for i in range(num_old - 1, -1, -1):
#     381                     al[i] = old_stps[i].dot(q) * ro[i]
# --> 382                     q.add_(old_dirs[i], alpha=-al[i])
#     383
#     384                 # multiply by initial Hessian
#
# KeyboardInterrupt:

# %%
nan_flag = train_model(max_iter,reps)

# %%
uvp_pred = PINN.forward(xyt_test_tensor).cpu().detach().numpy()

# %%
u_pred = uvp_pred[:,0].reshape(101,101,101)
v_pred = uvp_pred[:,1].reshape(101,101,101)

a = 10
b = 10
fig,axs = plt.subplots(3,2)

frame_idx = 19

ax = axs[0,0]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(u_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1],vmin = np.min(u_pred),vmax = np.max(u_pred))
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$u (t=0.2s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])


#-------------------------------------------------------------------

ax = axs[0,1]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(v_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1])
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=0.2s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

#--------------------------------------------------------------------------------------------------------
frame_idx = 59

ax = axs[1,0]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(u_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1],vmin = np.min(u_pred),vmax = np.max(u_pred))
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$u (t=0.6s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])


#-------------------------------------------------------------------

ax = axs[1,1]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(v_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1])
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=0.6s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

fig.subplots_adjust(wspace = 0.7)


#--------------------------------------------------------------------------------------------------------
frame_idx = 99

ax = axs[2,0]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(u_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1],vmin = np.min(u_pred),vmax = np.max(u_pred))
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$u (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])


#-------------------------------------------------------------------

ax = axs[2,1]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(v_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1])
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

fig.subplots_adjust(wspace = 0.1,hspace = 0.4)
# plt.savefig('NS_lid.svg', format='svg',pad_inches=0, bbox_inches='tight',transparent=True)

# %%
fig, ax = plt.subplots()
frame_idx = 99
ax.figure.set_size_inches(a,b)
psi = np.sqrt(np.square(v_pred[frame_idx,:,:]) + np.square(u_pred[frame_idx,:,:])) 
img = ax.imshow(np.flip(np.transpose(psi),axis =0),cmap = 'jet',extent= [0,1,0,1],vmax = 5,vmin = 0)
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

# plt.savefig('NS_lid.svg', format='svg',pad_inches=0, bbox_inches='tight',transparent=True)
# Out:
# (0.0, 1.0)

# %%
u_matlab = loadmat("uv_matlab.mat")['u']
v_matlab = loadmat("uv_matlab.mat")['v']

frame_idx = 100
fig,axs = plt.subplots(1,2)
a = 10
b = 3

fig.set_size_inches(a,b)

ax = axs[0]
ax.plot(y,u_matlab[50,:],'b-.',label = 'SOR')
ax.plot(y,u_pred[frame_idx,50,:],'r',label = 'PINN')
ax.set_xlim([0,1])
ax.legend()
ax.set_xlabel('$y$')
ax.set_ylabel('$u(x=0.5)$')
ax.set_title('Velocity in $x$-direction') 

ax = axs[1]
ax.plot(x,v_matlab[:,50],'b-.',label = 'SOR')
ax.plot(x,v_pred[frame_idx,:,50],'r',label = 'PINN')
ax.set_xlim([0,1])
ax.legend(loc = 1)
ax.set_xlabel('$x$')
ax.set_ylabel('$v(y=0.5)$')
ax.set_title('Velocity in $y$-direction') 

fig.subplots_adjust(wspace = 0.4)
# plt.savefig('SOR_PINN.svg', format='svg',bbox_inches = 'tight')

# %%
u_pred = u_matlab
v_pred = v_matlab

a = 10
b = 10
fig,axs = plt.subplots(1,2)

frame_idx = 99

ax = axs[0]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(u_pred[:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1],vmin = np.min(u_pred),vmax = np.max(u_pred))
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10,fraction=0.08)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$u (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])


#-------------------------------------------------------------------

ax = axs[1]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(v_pred[:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1])
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10,fraction=0.08)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

fig.subplots_adjust(wspace = 0.3)

# plt.savefig('NS_lid_SOR.svg', format='svg',pad_inches=0, bbox_inches='tight',transparent=True)

# %%
X, Y = np.meshgrid(np.linspace(0, 1, 101), np.linspace(0, 1, 101))
u = u_pred[frame_idx,:,:]  # Replace with your u values
v = v_pred[frame_idx,:,:]  # Replace with your v values
xstart =np.random.uniform()
ystart = np.random.uniform()  # Replace with your starting points
L = 1  # Replace with the desired value for L

# Create the streamline plot
# fig = plt.figure(3)
h = plt.streamplot(X, Y, u.T, v.T, start_points=np.column_stack([xstart, ystart]), color='k',linewidth=1.5, density=0.1, arrowstyle='->', arrowsize=1.5)
plt.title('Stream Function')
plt.xlabel('x-location')
plt.ylabel('y-location')
# plt.axis('equal', [0,1, 0, 1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_27642/1146078351.py in <module>
#       1 X, Y = np.meshgrid(np.linspace(0, 1, 101), np.linspace(0, 1, 101))
# ----> 2 u = u_pred[frame_idx,:,:]  # Replace with your u values
#       3 v = v_pred[frame_idx,:,:]  # Replace with your v values
#       4 xstart =np.random.uniform()
#       5 ystart = np.random.uniform()  # Replace with your starting points
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
p_pred = uvp_pred[:,2].reshape(100,100,100)
fig,ax = plt.subplots()
img = ax.imshow(np.flip(np.transpose(p_pred[99,:,:]),axis =0),cmap = 'jet')
fig.colorbar(img)
