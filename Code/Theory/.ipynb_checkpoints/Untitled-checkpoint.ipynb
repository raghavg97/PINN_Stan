# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-4,4,100)

sig = np.tanh(x)
sig1 = 1-np.square(sig)
sig2 = -2*sig*sig1

x_ax = 0*x;

# %%
fig,ax = plt.subplots()

ax.plot(x,x_ax,'k-.')
ax.plot(x_ax,x,'k-.')
ax.plot(x,sig,'b',label = 'tanh',linewidth = 3)
ax.plot(x,sig1,'r',label = '1st Derivative',linewidth = 3)
ax.plot(x,sig2,'m',label = '2nd Derivative',linewidth = 3)

ax.legend(loc = 2,fontsize = 14)

ax.set_xlim([-4,4])
ax.set_ylim([-1.1,1.1])

plt.savefig('tanh_derivs.svg', format='svg',pad_inches=0, bbox_inches='tight',transparent=True)

# %%
s = 0.3
np.random.seed(1234)
sig = np.random.normal(0,s,(1000,))
sig[sig>1] =1
sig[sig<-1] =-1

sig1 = np.random.normal(1-s**2,np.sqrt(2*s**4),(1000,))
# sig1[sig1>1] = 2-sig1[sig1>1]
sig1[sig1>1] = 1

sig2 = np.random.normal(0,np.sqrt(4*s**2*(15*s**4 - 6*s**2 + 1)),(1000,))

fig,ax = plt.subplots()

ax.hist(sig,color = 'b',bins = 25,alpha = 0.7,label = 'tanh')
ax.hist(sig1,color = 'r',bins = 25,alpha = 0.7,label = '1st Derivative')
ax.hist(sig2,color = 'm',bins = 25,alpha = 0.7,label = '2nd Derivative')
# Out:
# (array([  1.,   1.,   3.,   4.,  14.,  18.,  21.,  39.,  65.,  71.,  88.,
#          92., 106., 101.,  99.,  80.,  58.,  53.,  32.,  26.,  17.,   4.,
#           5.,   1.,   1.]),
#  array([-1.49948749, -1.38056684, -1.26164619, -1.14272553, -1.02380488,
#         -0.90488423, -0.78596357, -0.66704292, -0.54812227, -0.42920161,
#         -0.31028096, -0.19136031, -0.07243965,  0.046481  ,  0.16540165,
#          0.28432231,  0.40324296,  0.52216361,  0.64108427,  0.76000492,
#          0.87892557,  0.99784623,  1.11676688,  1.23568754,  1.35460819,
#          1.47352884]),
#  <BarContainer object of 25 artists>)
