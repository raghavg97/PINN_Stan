# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from torch.nn.parameter import Parameter

import numpy as np
import time
from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io

from smt.sampling_methods import LHS
from scipy.io import savemat

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

device = torch.device('cpu')

print(device)

import matplotlib.pyplot as plt

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cpu

# %%
algos = ['stan','tanh','atanh','swish','rowdy']
algo_labels = ['Stan (Proposed)','tanh','tanh(AF)','Swish','Rowdy']

layer_num = 1

max_steps = 75

colors = ['r','k','b--','g:','c-.']

fig,ax = plt.subplots(1,1)



for i in range(5):
    dat = scipy.io.loadmat('v_'+algos[i]+'.mat')
    v =  dat['v']


    ax.plot(range(0,75),v,colors[i],label = algo_labels[i])
    ax.set_xlim([0,75])
    ax.figure.set_size_inches(5,5)
    ax.set_yscale('log')



ax.set_xlabel('Epochs',fontsize=12,alpha = 1)
ax.set_ylabel('Value',fontsize=16,alpha = 1)
ax.legend()   
# ax.set_title("Layer "+str(layer_num+1),fontsize=18)
        
# fig.subplots_adjust(top = 2.0)   
fig.savefig('grads_plots.pdf', format='pdf', bbox_inches='tight')
